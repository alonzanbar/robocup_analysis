# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import numpy as np

# %%
with open('data/logs_exracted.json') as f:
    a = json.load(f)

# %%
df_logs = pd.DataFrame.from_dict({(i,j): a[i][j] 
                           for i in a.keys() 
                           for j in a[i].keys()},orient='index').reset_index()

df_logs= df_logs.fillna(0)
two_groups = '(?P<competition>[a-zA-Z\-]+)(?P<year>[0-9]+)'

df_logs = pd.concat([df_logs,df_logs['level_0'].str.extract(two_groups)],axis=1)
df_logs['year'] = df_logs['year'].astype('int64')
df_logs = df_logs.drop(['level_0'],axis=1)
df_logs['win_diff'] = df_logs.apply(lambda x: (x['win']-x['loss'])/x['games'],axis=1)
df_logs['win_rate'] = df_logs.apply(lambda x: (x['win'])/x['games'],axis=1)
df_logs['goals_diff'] = df_logs.apply(lambda x: float(x['S']-x['R'])/x['games'],axis=1)
df_logs['loss_rate'] = df_logs.apply(lambda x: (x['loss'])/x['games'],axis=1)
df_logs= df_logs.sort_values('win_diff')
df_logs =df_logs.rename({'level_1':'teamname'},axis='columns')

df_logs.head()
# Out:
#      teamname  loss  win  S   R  games  tie         competition  year  \
# 659  Ants2010   1.0  0.0  0   9      1  0.0          JapanOpens  2011
# 775       -RP   2.0  0.0  8  11      2  0.0  SpringCompetitions  2005
# 723     rione   1.0  0.0  0   8      1  0.0               PRIMA  2009
# 722     opuCI   1.0  0.0  0   2      1  0.0               PRIMA  2009
# 715  -one2010   5.0  0.0  0  15      5  0.0               PRIMA  2009
#
#      win_diff  win_rate  goals_diff  loss_rate
# 659      -1.0       0.0        -9.0        1.0
# 775      -1.0       0.0        -1.5        1.0
# 723      -1.0       0.0        -8.0        1.0
# 722      -1.0       0.0        -2.0        1.0
# 715      -1.0       0.0        -3.0        1.0

# %%
df_logs['team'] = [x.strip('_-').lower() for x in df_logs['teamname']]

# %%
df_results = pd.read_csv('data/competition_results.csv')

df_results.head()
# Out:
#    avg_goal_diff  avg_goals_scored country                dir  drawn  \
# 0       2.000000          3.000000  brazil   /home/itandroids      0
# 1      -2.000000          1.000000  brazil  /home/uaisoccer2d      0
# 2       2.000000          2.000000  brazil   /home/itandroids      0
# 3       0.333333          2.333333  brazil    /home/warthog2d      1
# 4      -0.666667          1.333333  brazil      /home/furgbot      2
#
#    goals_received  goals_scored  lost  matches  points  score  team  \
# 0               1             3     0        1       3    NaN   NaN
# 1               3             1     1        1       0    NaN   NaN
# 2               0             6     0        3       9    NaN   NaN
# 3               6             7     1        3       4    NaN   NaN
# 4               6             4     1        3       2    NaN   NaN
#
#       teamname  won  year competition
# 0   ITAndroids    1  2013         CBR
# 1  UAISoccer2D    0  2013         CBR
# 2   ITAndroids    3  2013         CBR
# 3      Warthog    1  2013         CBR
# 4      Furgbot    0  2013         CBR

# %%
df_results_sum = df_results.groupby(['competition','year','teamname']).sum().reset_index()

# %%
df1 = df_logs.merge(df_results_sum,how='inner',on=['competition','year','teamname'])[['competition','year','teamname','games','matches']]

# %%
diffs = df1[['games','matches']].apply(lambda x: x[0]-x[1],axis=1)

# %%
diffs.describe()
# Out:
# count    122.000000
# mean      -0.172131
# std        2.967295
# min       -4.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        0.000000
# max       13.000000
# dtype: float64

# %%
df1[['games','matches']].corr()
# Out:
#             games   matches
# games    1.000000  0.960945
# matches  0.960945  1.000000

# %%
df1['games'].hist()

# %% [markdown]
# ## Data validation :

# %% [markdown]
# ### correlation between goals scores and and wins

# %%
df_logs[['win','S']].corr()
# Out:
#           win         S
# win  1.000000  0.952096
# S    0.952096  1.000000

# %% [markdown]
# ### correlation between goals recived and losses

# %%
df_logs[['loss','R']].corr()
# Out:
#           loss         R
# loss  1.000000  0.937892
# R     0.937892  1.000000

# %%
df_logs[df_logs['games']==0]
# Out:
# Empty DataFrame
# Columns: [teamname, loss, win, S, R, games, tie, competition, year, win_diff, win_rate, goals_diff, loss_rate, team]
# Index: []

# %%
df_ranks_raw = pd.read_csv('data/ranks_wiki.csv')
df_ranks_raw
# Out:
#     Year 1st Place Team 2nd Place Team    3rd Place Team
# 0   2016    Gliders2016     HELIOS2016            Ri-one
# 1   2015    WrightEagle     HELIOS2015       Gliders2015
# 2   2014    WrightEagle    Gliders2014              Oxsy
# 3   2013    WrightEagle     HELIOS2013        YuShan2013
# 4   2012     HELIOS2012    WrightEagle            MarIiK
# 5   2011    WrightEagle     HELIOS2011            MarliK
# 6   2010         HELIOS    WrightEagle              Oxsy
# 7   2009    WrightEagle         HELIOS              Oxsy
# 8   2008  Brainstormers    WrightEagle            HELIOS
# 9   2007  Brainstormers    WrightEagle            HELIOS
# 10  2006    WrightEagle  Brainstormers            Ri-one
# 11  2005  Brainstormers    WrightEagle      TokyoTechSFC
# 12  2004   STEP, Russia  Brainstormers            Mersad
# 13  2003   UvA Trilearn  TsinghuAeolus     Brainstormers
# 14  2002  TsinghuAeolus        Everest     Brainstormers
# 15  2001  TsinghuAeolus  Brainstormers       FC Portugal
# 16  2000    FC Portugal  Brainstormers       ATTCMUnited
# 17  1999       CMUnited  magmaFreiburg     Essex Wizards
# 18  1998       CMUnited   AT Humboldt,  WindmillWanderer
# 19  1997    AT Humboldt        Andhill              ISIS

# %%
df_ranks_raw.shape[0]
# Out:
# 20

# %%
results = [] 
for _,r in df_ranks_raw.iterrows(): 
    results +=  [(r.Year,r[c].lower(),4-int(c[0])) for c in df_ranks_raw.columns[1:]]

# %%
df_ranks = pd.DataFrame(results,columns=['year','team','rank'])

# %%
df_ranks_logs= df_ranks.merge(df_logs[df_logs['competition']=='WorldCup'],on=['year'],how='inner')
matched_df = df_ranks_logs[df_ranks_logs.apply(lambda x: x['team_x'] in x['team_y'],axis=1)]

# %%
notfound = df_ranks.merge(matched_df,left_on=['year','team'],right_on=['year','team_x'],how='left',indicator=True)
notfound = notfound[notfound['_merge']=='left_only']

# %%
notfound
# Out:
#     year              team  rank_x team_x  rank_y teamname  loss  win   S   R  \
# 2   2016            ri-one       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 25  2008       wrighteagle       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 28  2007       wrighteagle       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 30  2006       wrighteagle       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 32  2006            ri-one       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 34  2005       wrighteagle       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 35  2005      tokyotechsfc       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 36  2004      step, russia       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 39  2003      uva trilearn       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 48  2001       fc portugal       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 49  2000       fc portugal       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 50  2000     brainstormers       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 51  2000       attcmunited       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 52  1999          cmunited       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 53  1999     magmafreiburg       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 54  1999     essex wizards       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 55  1998          cmunited       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 56  1998      at humboldt,       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 57  1998  windmillwanderer       1    NaN     NaN      NaN   NaN  NaN NaN NaN
# 58  1997       at humboldt       3    NaN     NaN      NaN   NaN  NaN NaN NaN
# 59  1997           andhill       2    NaN     NaN      NaN   NaN  NaN NaN NaN
# 60  1997              isis       1    NaN     NaN      NaN   NaN  NaN NaN NaN
#
#     games  tie competition  win_diff  win_rate  goals_diff  loss_rate team_y  \
# 2     NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 25    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 28    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 30    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 32    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 34    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 35    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 36    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 39    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 48    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 49    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 50    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 51    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 52    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 53    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 54    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 55    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 56    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 57    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 58    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 59    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
# 60    NaN  NaN         NaN       NaN       NaN         NaN        NaN    NaN
#
#        _merge
# 2   left_only
# 25  left_only
# 28  left_only
# 30  left_only
# 32  left_only
# 34  left_only
# 35  left_only
# 36  left_only
# 39  left_only
# 48  left_only
# 49  left_only
# 50  left_only
# 51  left_only
# 52  left_only
# 53  left_only
# 54  left_only
# 55  left_only
# 56  left_only
# 57  left_only
# 58  left_only
# 59  left_only
# 60  left_only

# %%
df_logs[df_logs['year']==2016]
# Out:
#             teamname  loss   win   S   R  games   tie competition  year  \
# 1294       LeftEagle   7.0   0.0   2  29      7   0.0    WorldCup  2016
# 1301            _GPR   9.0   2.0   7  23     11   0.0    WorldCup  2016
# 1300        Ziziphus  14.0   3.0  13  49     21   4.0    WorldCup  2016
# 1293      ITAndroids  14.0   6.0  15  45     21   1.0    WorldCup  2016
# 1292       HillStone  15.0   7.0  33  70     23   1.0    WorldCup  2016
# 1291  HfutEngine2016   3.0   1.0   3   5      7   3.0    WorldCup  2016
# 1298      Shiraz2016  12.0   7.0  19  50     22   3.0    WorldCup  2016
# 1286           CYRUS  11.0   7.0  24  42     22   4.0    WorldCup  2016
# 1296      MarliK2016  11.0   7.0  14  25     22   4.0    WorldCup  2016
# 1287            FURY  10.0   7.0  21  28     22   5.0    WorldCup  2016
# 1285            -one  10.0   9.0  32  39     24   5.0    WorldCup  2016
# 1302          _Yunlu   7.0   7.0  24  23     23   9.0    WorldCup  2016
# 1284         -UNIted   7.0   7.0  16  17     22   8.0    WorldCup  2016
# 361         ziziphus   0.0   0.0   0   0     17  17.0   IranOpens  2016
# 360          razicup   0.0   0.0   0   0     10  10.0   IranOpens  2016
# 359           paydar   0.0   0.0   0   0     10  10.0   IranOpens  2016
# 357             fury   0.0   0.0   0   0      3   3.0   IranOpens  2016
# 356            cyrus   0.0   0.0   0   0     10  10.0   IranOpens  2016
# 355           Shiraz   0.0   0.0   0   0     17  17.0   IranOpens  2016
# 354             STRT   0.0   0.0   0   0      3   3.0   IranOpens  2016
# 353            Riton   0.0   0.0   0   0     10  10.0   IranOpens  2016
# 352          QASHQAI   0.0   0.0   0   0     10  10.0   IranOpens  2016
# 351          Nexus2D   0.0   0.0   0   0     11  11.0   IranOpens  2016
# 350      Miracle2016   0.0   0.0   0   0     11  11.0   IranOpens  2016
# 349           MT2016   0.0   0.0   0   0     18  18.0   IranOpens  2016
# 348        Lightning   0.0   0.0   0   0     11  11.0   IranOpens  2016
# 347        LegenDary   0.0   0.0   0   0     17  17.0   IranOpens  2016
# 346           ENIGMA   0.0   0.0   0   0      3   3.0   IranOpens  2016
# 358          khayyam   0.0   0.0   0   0      3   3.0   IranOpens  2016
# 1297            Oxsy   7.0  12.0  54  22     23   4.0    WorldCup  2016
# 1290          HERMES   6.0  11.0  40  16     22   5.0    WorldCup  2016
# 1295          MT2016   5.0  11.0  45  20     22   6.0    WorldCup  2016
# 1299     WrightEagle   3.0  12.0  56  10     15   0.0    WorldCup  2016
# 1289      HELIOS2016   2.0  20.0  55   6     26   4.0    WorldCup  2016
# 1288     Gliders2016   2.0  19.0  58  12     23   2.0    WorldCup  2016
#
#       win_diff  win_rate  goals_diff  loss_rate            team
# 1294 -1.000000  0.000000   -3.857143   1.000000       lefteagle
# 1301 -0.636364  0.181818   -1.454545   0.818182             gpr
# 1300 -0.523810  0.142857   -1.714286   0.666667        ziziphus
# 1293 -0.380952  0.285714   -1.428571   0.666667      itandroids
# 1292 -0.347826  0.304348   -1.608696   0.652174       hillstone
# 1291 -0.285714  0.142857   -0.285714   0.428571  hfutengine2016
# 1298 -0.227273  0.318182   -1.409091   0.545455      shiraz2016
# 1286 -0.181818  0.318182   -0.818182   0.500000           cyrus
# 1296 -0.181818  0.318182   -0.500000   0.500000      marlik2016
# 1287 -0.136364  0.318182   -0.318182   0.454545            fury
# 1285 -0.041667  0.375000   -0.291667   0.416667             one
# 1302  0.000000  0.304348    0.043478   0.304348           yunlu
# 1284  0.000000  0.318182   -0.045455   0.318182          united
# 361   0.000000  0.000000    0.000000   0.000000        ziziphus
# 360   0.000000  0.000000    0.000000   0.000000         razicup
# 359   0.000000  0.000000    0.000000   0.000000          paydar
# 357   0.000000  0.000000    0.000000   0.000000            fury
# 356   0.000000  0.000000    0.000000   0.000000           cyrus
# 355   0.000000  0.000000    0.000000   0.000000          shiraz
# 354   0.000000  0.000000    0.000000   0.000000            strt
# 353   0.000000  0.000000    0.000000   0.000000           riton
# 352   0.000000  0.000000    0.000000   0.000000         qashqai
# 351   0.000000  0.000000    0.000000   0.000000         nexus2d
# 350   0.000000  0.000000    0.000000   0.000000     miracle2016
# 349   0.000000  0.000000    0.000000   0.000000          mt2016
# 348   0.000000  0.000000    0.000000   0.000000       lightning
# 347   0.000000  0.000000    0.000000   0.000000       legendary
# 346   0.000000  0.000000    0.000000   0.000000          enigma
# 358   0.000000  0.000000    0.000000   0.000000         khayyam
# 1297  0.217391  0.521739    1.391304   0.304348            oxsy
# 1290  0.227273  0.500000    1.090909   0.272727          hermes
# 1295  0.272727  0.500000    1.136364   0.227273          mt2016
# 1299  0.600000  0.800000    3.066667   0.200000     wrighteagle
# 1289  0.692308  0.769231    1.884615   0.076923      helios2016
# 1288  0.739130  0.826087    2.000000   0.086957     gliders2016

# %%
df_ranks_logs.to_csv('checkpoints/logs-ranks.csv')
df_ranks_logs.head()
# Out:
#    year         team  rank     teamname  loss   win   S   R  games  tie  \
# 0  2016  Gliders2016     3  Gliders2016   2.0  19.0  58  12     23  2.0
# 1  2016   HELIOS2016     2   HELIOS2016   2.0  20.0  55   6     26  4.0
# 2  2015  WrightEagle     3  WrightEagle   3.0  16.0  56  13     21  2.0
# 3  2015   HELIOS2015     2   HELIOS2015   1.0  17.0  51   8     21  3.0
# 4  2015  Gliders2015     1  Gliders2015   1.0  18.0  65   7     23  4.0
#
#   competition  win_diff  win_rate  goals_diff  loss_rate
# 0    WorldCup  0.739130  0.826087    2.000000   0.086957
# 1    WorldCup  0.692308  0.769231    1.884615   0.076923
# 2    WorldCup  0.619048  0.761905    2.047619   0.142857
# 3    WorldCup  0.761905  0.809524    2.047619   0.047619
# 4    WorldCup  0.739130  0.782609    2.521739   0.043478

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df_ranks_logs,x='S',y='rank').set_title('Total Goals Scored Vs rank')
# Out:
# Text(0.5,1,'Total Goals Scored Vs rank')

# %%
sns.scatterplot(data=df_ranks_logs,x='win_diff',y='rank').set_title('Wins-Losses / Games  vs Rank')
# Out:
# Text(0.5,1,'Wins-Losses / Games  vs Rank')

# %%
sns.scatterplot(data=df_ranks_logs,x='win_rate',y='rank').set_title('wins / games vs rank')
# Out:
# Text(0.5,1,'wins / games vs rank')

# %%
sns.scatterplot(data=df_ranks_logs,x='goals_diff',y='rank').set_title('goals diff vs rank')
# Out:
# Text(0.5,1,'goals diff vs rank')

# %%
sns.scatterplot(data=df_ranks_logs,x='loss_rate',y='rank').set_title('loss rate vs rank')
# Out:
# Text(0.5,1,'loss rate vs rank')
