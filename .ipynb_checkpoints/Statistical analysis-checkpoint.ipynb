# %%
import matplotlib
import  pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
import numpy.ma as ma

# %%
df =  pd.read_csv(os.getcwd() +"/data/data.csv",index_col=0)

# %%
df.groupby('category').count()['type'].plot(kind='bar')

# %%
low = .01
high = .97
quant_df = df['analizo_accm_mean'].quantile([low, high])
quant_df
# Out:
# 0.01    1.110819
# 0.97    6.120673
# Name: analizo_accm_mean, dtype: float64

# %%
df_reduced =df.loc[df['analizo_accm_mean']<=quant_df[high]].copy()

# %%
df_reduced.groupby('category').median()['analizo_accm_mean'].sort_values(ascending=False).plot(kind='bar',figsize=(15,10))

# %%
df_reduced.groupby('category').median()['analizo_acc_mean'].sort_values(ascending=False).plot(kind='bar',figsize=(10,5))

# %%
from scipy import stats
from operator import itemgetter

# %%
diff_vars = []
cat_lst = list(df_reduced[df_reduced['agent_type']=='agent']['category'].unique())
cat_lst.extend(df_reduced[df_reduced['agent_type']=='non-agent']['category'].unique())

# %%
variables = list(df_reduced.select_dtypes(include=[np.number]).columns)

# %%
diff_vars = {}
rep1= set()
for var in variables:
    ks_stats = []        
    rvs2 = df_reduced[(df_reduced['agent_type']=='non-agent')][var]
    for cat in cat_lst:
        rvs1 = df_reduced[df_reduced['category']==cat][var]
        
        p = stats.ttest_ind(rvs1, rvs2)[1]
        ks_stats.append((p<0.005)&(rvs1.mean()>rvs2.mean()) )
    if np.count_nonzero(ks_stats)>=3:
        cat_arr = np.array(cat_lst)[ks_stats]
        rep1 |= set(cat_arr)
        diff_vars[var] = [cat_arr,p]
diff_vars
            #sorted (ks_stats,key=itemgetter(1))
# Out:
# {'analizo_accm_mean': [array(['robocup-2d', 'chess', 'anac'], dtype='|S16'),
#   0.053215406760068404],
#  'analizo_accm_quantile_median': [array(['robocup-2d', 'chess', 'anac'], dtype='|S16'),
#   0.00851888609927462],
#  'analizo_accm_quantile_upper': [array(['robocup-2d', 'chess', 'anac'], dtype='|S16'),
#   0.15695577819039203],
#  'analizo_amloc_quantile_median': [array(['robocup-2d', 'chess', 'anac'], dtype='|S16'),
#   0.09862869870623309],
#  'analizo_amloc_quantile_upper': [array(['robocup-2d', 'chess', 'anac', 'robot-simulation'], dtype='|S16'),
#   0.47981432427860016],
#  'analizo_anpm_mean': [array(['robocup-2d', 'anac', 'Graphics'], dtype='|S16'),
#   0.11585558190741492],
#  'analizo_anpm_quantile_upper': [array(['robocup-2d', 'anac', 'Graphics'], dtype='|S16'),
#   0.21252426870996075],
#  'analizo_anpm_variance': [array(['robocup-2d', 'anac', 'Graphics'], dtype='|S16'),
#   0.4689903638593149],
#  'analizo_mmloc_quantile_upper': [array(['robocup-2d', 'anac', 'robot-simulation'], dtype='|S16'),
#   0.014765853997404123]}

# %%
rep1 =list(rep1)
# Out:
# {'Graphics', 'anac', 'chess', 'robocup-2d', 'robot-simulation'}

# %%
diff_v = {k[k.find('_')+1:]: [ 1 if r in v else 0 for r in rep1[0]] for k,v in diff_vars.iteritems()}
diff_v
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-64-0d999deb6a33> in <module>()
# ----> 1 diff_v = {k[k.find('_')+1:]: [ 1 if r in v else 0 for r in rep1[0]] for k,v in diff_vars.iteritems()}
#       2 diff_v
#
# <ipython-input-64-0d999deb6a33> in <dictcomp>((k, v))
# ----> 1 diff_v = {k[k.find('_')+1:]: [ 1 if r in v else 0 for r in rep1[0]] for k,v in diff_vars.iteritems()}
#       2 diff_v
#
# TypeError: 'set' object does not support indexing

# %%
df =  pd.DataFrame.from_dict(diff_v,orient='index',columns=rep1)
df
# Out:
#                        robocup-2d  robot-simulation  anac  chess  Graphics
# accm_quantile_median            1                 0     1      1         0
# amloc_quantile_upper            1                 1     1      1         0
# anpm_variance                   1                 0     1      0         1
# amloc_quantile_median           1                 0     1      1         0
# anpm_mean                       1                 0     1      0         1
# accm_quantile_upper             1                 0     1      1         0
# accm_mean                       1                 0     1      1         0
# anpm_quantile_upper             1                 0     1      0         1
# mmloc_quantile_upper            1                 1     1      0         0

# %%
pd.pivot_table(data=diff_vars columns=)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-12-7074013bb6a8> in <module>()
# ----> 1 pd.pivot_tab
#
# AttributeError: 'module' object has no attribute 'pivot_tab'

# %%
for var in diff_vars:
    
    fix,ax = plt.subplots(figsize=(15,10),)
    g = sns.boxplot(x='category',y=var,data=df_reduced).set_title(var)
    g = sns.swarmplot(x='category',y=var,data=df_reduced,color='black')
    for item in g.get_xticklabels():
         item.set_rotation(90)

# %%
for var in [c for c in variables if 'mean'  in c]:
    
    fix,ax = plt.subplots(figsize=(7,3))
    g = sns.boxplot(x='category',y=var,data=df_reduced)
    g.set_title(var)
    #g = sns.swarmplot(x='category',y=var,data=df_reduced,color='black')
    for item in g.get_xticklabels():
         item.set_rotation(90)

# %%
df2 =  pd.read_csv(os.getcwd() +"/data/robo-sim-data.csv",index_col=0)

# %%
df2 = df2[~df2['McCabes_cyclomatic_complexity'].isnull()].copy()

# %%
df2['cc_per_line_of_code'] = df2['McCabes_cyclomatic_complexity'] / df2['analizo_total_loc']

# %%
df2['McCabes_cyclomatic_complexity'].hist(range=(0,2500))

# %%
df2.plot.scatter(x='analizo_accm_mean',y='cc_per_line_of_code' )
plt.ylim(0,1)
# Out:
# (0, 1)
