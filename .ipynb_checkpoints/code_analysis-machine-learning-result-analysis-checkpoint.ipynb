# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

model_file_name = 'agent_type_1vsAll'

# %%
_,result_l = pickle.load(open('checkpoints/'+model_file_name + '.model'))

# %%
pd.set_option('max_colwidth',100)

# %%
#resluts_df = resluts_df.sort_values('f1_score',ascending=False)
res_df = resluts_df['SGD']
res_df['auc'] = 1- res_df['auc']
res_df = res_df.round(2)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-104-a9e0fc779921> in <module>()
#       1 #resluts_df = resluts_df.sort_values('f1_score',ascending=False)
# ----> 2 res_df = resluts_df['SGD']
#       3 res_df['auc'] = 1- res_df['auc']
#       4 res_df = res_df.round(2)
#
# KeyError: 'SGD'

# %%
res_df = res_df.sort_values('f1_score',ascending=False).reset_index()
res_df['auc'] = 1 - res_df['auc']
print(res_df[['agent_type','type_class','auc','f1_score','feature_importance']].to_latex())
# Out:
# \begin{tabular}{llllrl}
# \toprule
# {} & agent\_type &            type\_class &  auc &  f1\_score &                                                                                   feature\_importance \\
# \midrule
# 0  &      agent &            Robocup-2D &  NaN &      0.67 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 1  &      agent &                  Anac &  NaN &      0.67 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 2  &  non-agent &      Robot-Simulation &  NaN &      0.24 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 3  &  non-agent &              Graphics &  NaN &      0.20 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 4  &  non-agent &                 Games &  NaN &      0.11 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 5  &      Robot &  Robcup-Other-Leagues &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 6  &  non-agent &              Security &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 7  &  non-agent &                Mobile &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 8  &  non-agent &                   Ide &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 9  &  non-agent &               Finance &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 10 &  non-agent &             Education &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 11 &  non-agent &                 Audio &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 12 &      agent &                 Chess &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# 13 &      Robot &         Robo-Projects &  NaN &      0.00 &  RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class\_weight=None,\textbackslash n       early\_stoppi... \\
# \bottomrule
# \end{tabular}

# %%
import pickle
pickle.dump(res_df,open('mk-results.sav','w+'))

# %%
ordered_list = ['Robocup-2D',
 'Anac',
 'Chess',
'Robo-Projects',
 'Robot-Simulation',
 'Graphics',
 'Ide',
 'Mobile',
 'Security',
 'Games',
 'Audio',
 'Finance',
 'Education',
'Robo-Projects']

# %%
res_df = result_l[result_l['model_name']=='Boosted Trees']
df_l = res_df.sort_values('auc',ascending=False)
lw=1
l = df_l.shape[0]
cols = l % 5
rows = l / cols +1
plt.figure(figsize=(12,8))
for i, res in enumerate(df_l.iterrows()):
    res  = res[1]
    plt.subplot(cols,rows,i+1)
    plt.plot(res['tpr'],res['fpr'],
         lw=lw, label="({0} {1} (area={2:.2f})".format(i,res['type_class'],res['auc'])) 
    plt.plot([0, 1], [0, 1], lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.title("({0}) {1} (area={2:.2f})".format(i,res['type_class'],res['auc']))
    #plt.legend(loc="upper left")
    plt.grid(True)
plt.tight_layout()
plt.savefig('fig/'+model_file_name+'_ml-auc-results.eps',dpi=1200,format='eps')
plt.show();

# %%
df_reduced['agent_type'].unique()
# Out:
# array(['agent', 'Robot', 'non-agent'], dtype=object)

# %%
from mlxtend.plotting import plot_decision_regions
from xgboost import XGBClassifier
from sklearn import linear_model
classification_series = result_l.iloc[2,:]
clf = classification_series['model']
seleted2= classification_series['feature rank'][:2]

# %%
import copy
new_clf = copy.deepcopy(clf)
X = df_reduced[seleted2].values
Y = df_reduced['agent_type']==classification_series.type_class
Y = Y.values.astype(np.integer)
new_clf.fit(X,Y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=nan, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
plt.figure(figsize=(20,10))
with plt.style.context({'lines.markersize': 10}):
    ax = plot_decision_regions(X,Y,clf=new_clf)
L=plt.legend()
L.get_texts()[0].set_text('Agent')
L.get_texts()[1].set_text('Non Agent')

# Adding axes annotations
plt.xlabel(seleted2[0])
plt.ylabel(seleted2[1])
plt.title('Classification of agent types')
# Out:
# Text(0.5,1,'Classification of agent types')

# %%
import time

from sklearn.manifold import TSNE

n_sne = 7000

time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=50, n_iter=3000)
tsne_results = tsne.fit_transform(df_reduced.select_dtypes(include=[np.number]).values)

print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 525 samples in 0.000s...
# [t-SNE] Computed neighbors for 525 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 525 / 525
# [t-SNE] Mean sigma: 6.242544
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.542839
# [t-SNE] KL divergence after 3000 iterations: 0.466820
# t-SNE done! Time elapsed: 28.7078678608 seconds

# %%
import seaborn as sns
df_reduced['x-tsne'] = tsne_results[:,0]
df_reduced['y-tsne'] = tsne_results[:,1]
fig,ax = plt.subplots(figsize=(16,10))
sns.scatterplot(ax=ax,data=df_reduced,x='x-tsne',y='y-tsne' ,hue='agent_type')
