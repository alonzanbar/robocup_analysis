# %%
import pandas as pd
import json 
import re
import numpy as np

# %%
df_metrics = pd.read_csv('../data/2d-03_10_2018.csv')
df_metrics.shape[0]
# Out:
# 516

# %%
with open('../data/logs_exracted.json') as f:
    a = json.load(f)
df_logs = pd.DataFrame.from_dict({(i,j): a[i][j] 
                           for i in a.keys() 
                           for j in a[i].keys()},orient='index').reset_index()

df_logs= df_logs.fillna(0)
df_logs['win_diff'] = df_logs.apply(lambda x: (x['win']-x['loss'])/x['games'],axis=1)
df_logs['win_rate'] = df_logs.apply(lambda x: (x['win'])/x['games'],axis=1)
df_logs['goals_diff'] = df_logs.apply(lambda x: float(x['S']-x['R'])/x['games'],axis=1)
df_logs['loss_rate'] = df_logs.apply(lambda x: (x['loss'])/x['games'],axis=1)
df_logs = df_logs.rename({k:'results_' + k for k in df_logs.select_dtypes(include=np.number)},axis=1)
two_groups = '(?P<competition>[a-zA-Z\-\_]+)(?P<year>[0-9]+)'

df_logs = pd.concat([df_logs,df_logs['level_0'].str.extract(two_groups)],axis=1)
df_logs['year'] = df_logs['year'].astype('int64')
df_logs = df_logs.drop(['level_0'],axis=1)
df_logs = df_logs.rename({'level_1':'team'},axis=1)




df_logs.tail()
# Out:
#                  team  results_loss  results_S  results_R  results_games  \
# 1288          nexus2d           4.0          8         14              6
# 1289             oxsy           0.0         19          3              6
# 1290  persiangulf2017           2.0          6         12              6
# 1291              wit           6.0          0         22              6
# 1292         ziziphus           4.0          4         18              6
#
#       results_tie  results_win  results_win_diff  results_win_rate  \
# 1288          0.0          2.0         -0.333333          0.333333
# 1289          0.0          6.0          1.000000          1.000000
# 1290          2.0          2.0          0.000000          0.333333
# 1291          0.0          0.0         -1.000000          0.000000
# 1292          1.0          1.0         -0.500000          0.166667
#
#       results_goals_diff  results_loss_rate competition  year
# 1288           -1.000000           0.666667    WorldCup  2017
# 1289            2.666667           0.000000    WorldCup  2017
# 1290           -1.000000           0.333333    WorldCup  2017
# 1291           -3.666667           1.000000    WorldCup  2017
# 1292           -2.333333           0.666667    WorldCup  2017

# %%
df_logs['team'] = [x.strip('_-') for x in df_logs['team']]

# %%
df_logs['competition'] = df_logs['competition'].str.replace(u'JapanAutumnCamp','AutumnCamp')

# %%
df_logs.to_csv('../data/logs_extracted.csv')

# %%
df_logs['team'] = df_logs['team'].str.lower()

# %%
df_logs = df_logs.groupby(['year','competition','team']).sum().reset_index()

# %%
df_logs.shape[0]
# Out:
# 1291

# %%
df_logs = df_logs[~(df_logs['team'].str.len()<3)]

# %% [markdown]
# #### Load manually linked logs to program

# %%
df_mapped = pd.read_csv('../data/group_names_mapped.csv',usecols=['competition','year','team_manual','group_name'])
df_mapped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 4 columns):
# competition    528 non-null object
# group_name     528 non-null object
# year           528 non-null int64
# team_manual    63 non-null object
# dtypes: int64(1), object(3)
# memory usage: 16.6+ KB

# %%
df_mapped[df_mapped['year']==2012]
# Out:
#     competition                    group_name  year team_manual
# 413  ChinaOpens                      apollo2d  2012         NaN
# 414  ChinaOpens                         aua2d  2012         NaN
# 415  ChinaOpens                          bjut  2012         NaN
# 416  ChinaOpens                     csu_yunlu  2012         NaN
# 417  ChinaOpens                   dreamwing2d  2012         NaN
# 418  ChinaOpens                 gdut_tiji2012  2012         NaN
# 419  ChinaOpens                    hfutengine  2012         NaN
# 420  ChinaOpens                       hfuu-mt  2012         NaN
# 421  ChinaOpens                 lntu_taac2012  2012         NaN
# 422  ChinaOpens                   miracle2012  2012         NaN
# 423  ChinaOpens                          tjnu  2012         NaN
# 424  ChinaOpens                       tornado  2012         NaN
# 425  ChinaOpens                   wonderpines  2012         NaN
# 426  ChinaOpens                   wrighteagle  2012         NaN
# 427  ChinaOpens                         xmunq  2012         NaN
# 428  ChinaOpens                    yushan2012  2012         NaN
# 429    WorldCup                 AUT_2D_Source  2012         NaN
# 430    WorldCup      Axiom_Binary_Release2012  2012         NaN
# 431    WorldCup  Axiom_SourceCode_Release2012  2012         NaN
# 432    WorldCup                    borregos2d  2012         NaN
# 433    WorldCup                  fcportugal2d  2012         NaN
# 434    WorldCup              fcportugal2d_src  2012         NaN
# 435    WorldCup                     gdut_tiji  2012         NaN
# 436    WorldCup                   gliders2012  2012         NaN
# 437    WorldCup                        gpr-2d  2012         NaN
# 438    WorldCup                    itandroids  2012         NaN
# 439    WorldCup                        marlik  2012      mariik
# 440    WorldCup                      nadco-2d  2012         NaN
# 441    WorldCup                          oxsy  2012         NaN
# 442    WorldCup                        ri-one  2012         NaN
# 443    WorldCup                         riton  2012         NaN
# 444    WorldCup  robotto_soccer_simulation_2d  2012         NaN
# 445    WorldCup               WarthogRobotics  2012         NaN
# 446    WorldCup        WarthogRobotics-RC2012  2012         NaN
# 447    WorldCup                   WrightEagle  2012         NaN
# 448    WorldCup                        yushan  2012         NaN

# %%
df_merged_mapping = df_logs.merge(df_mapped,left_on=['competition','year','team'],right_on=['competition','year','team_manual'],how='left')
df_merged_mapping['team_alt'] = df_merged_mapping.apply(lambda x: x.group_name if pd.notnull(x.group_name) else x.team ,axis=1)

# %%
df_merged_mapping.shape[0]
# Out:
# 1257

# %%
df_merged_mapping = df_merged_mapping.drop('group_name',axis=1)

# %% [markdown]
# #### number manually linked programs :

# %%
df_merged_mapping.shape[0]
# Out:
# 1257

# %% [markdown]
# #### Number of not liked groups

# %% [markdown]
# ###  linking groups to logs
# Iterative process (The proccess in repeated until no new couples are found ):
# 1. building joining hurstics  based on manuall discovered general convestion ( lower, sub strings ... )
# 2. Manually connecting between names of team in the logs and names in code repos for team that in cases where the join logic doesn't generlize
# 3. linking automatically based on huristic and manual link 4. listing all the unlinked teams / groups

# %%
# join logic between team name in the logs and group name in the program repository folder 
def is_in_group(x,):
    r= re.match(r'([a-zA-Z\-]+)',x.team_alt)
    r2 = re.match(r'([a-zA-Z\-0-9]+)',x.team_alt)
    if not r:
        return False
    return r.groups()[0].lower() in x.group_name.lower(), len(r2.groups()[0])

# %%
# hanldes cases where the team name apears twice in different format 
def len_in_group_dup(x):
    if x.duplicate_team < 2: 
        return True
    r= re.match(r'([a-zA-Z\-0-9]+)',x.team_alt)
    if not r:
        return False
    if r.groups()[0].lower() in x.group_name.lower():
        return len(r.groups()[0])

# %%
df_mix = df_metrics.merge(df_merged_mapping,on=['competition','year'])

# %%
df_mix = df_mix.join(df_mix.apply(is_in_group,axis=1,result_type='expand').
                     rename({0:'exist',1:'length'},axis=1))

# %%
df = df_mix[df_mix['exist']==True].copy()

# %%
df.loc[:,'max'] = df.groupby(['competition','year','group_name'])['length'].transform(max)

# %%
df = df[df['length']==df['max']]

# %%
g = df.groupby(['competition','year','group_name'])['Current_group_location'].transform(lambda x: x.count())

# %%
df_metrics.shape[0]
# Out:
# 516

# %%
df1 = df_metrics.merge(df,on=['competition','year','group_name'],how='left',indicator=True)
df1[df1['_merge']=='both'].shape[0]
# Out:
# 413

# %%
df1[['competition','group_name','year','team_manual','_merge','is_source_x']].sort_values(['year','group_name']).to_csv('../checkpoints/not_found_group_names.csv')

# %%
df2 = df_logs.merge(df,how='left',on=['competition','year','team'])

# %%
df_logs.count()
# Out:
# year                  1251
# competition           1251
# team                  1251
# results_loss          1251
# results_S             1251
# results_R             1251
# results_games         1251
# results_tie           1251
# results_win           1251
# results_win_diff      1251
# results_win_rate      1251
# results_goals_diff    1251
# results_loss_rate     1251
# dtype: int64

# %%
df2[(df2['group_name'].isnull())][['competition','year','team']].sort_values(['competition','year','team']).to_csv('../checkpoints/not_found_team.csv')

# %%
r= re.match(r'([a-zA-Z\-0-9]+)','oxblue08')

# %%
r.group(0).lower()
# Out:
# 'oxblue08'

# %%
'OxBlue_rc08_release'.lower()
# Out:
# 'oxblue_rc08_release'

# %%
df.to_csv('../data/merged-logs_repo.csv')

# %%
df1[(df1['is_source_x']==True) & (df1['_merge']=='left_only')]
# Out:
#                          Current_group_location_x  \
# 55   2000_WorldCup_BS2K_Melbourne2000_CodeRelease
# 58             2001_WorldCup_FuzzyFoo-2001-source
# 68                        1998_WorldCup_andhill98
# 90                    1996_WorldCup_sekine_client
# 97                        2000_WorldCup_RC2000-oz
# 147                           1998_WorldCup_ath97
# 253               1997_WorldCup_andhill_RoboCup97
# 279                    2008_JapanOpens_BKB_jin_AI
# 311                       1999_WorldCup_CoachRC99
# 312                           1997_WorldCup_agent
# 333               1997_WorldCup_CMUnited97-source
# 351                    2001_WorldCup_parsai-code1
# 414                           1997_WorldCup_ath97
# 424                  1996_WorldCup_ogalets-ver3_x
# 429                 1997_WorldCup_RoboCup-97-ISIS
# 439                       1999_WorldCup_kit0726v4
# 443           1999_WorldCup_Zeng99-source-release
# 487                         1996_WorldCup_ogalets
# 504                    1999_WorldCup_ew99_sources
# 506                        1998_WorldCup_Kappa_v0
#
#                                            Exe_files_x      IF4_x  \
# 55                                                 NaN      558.0
# 58                                                 NaN        NaN
# 68                                                 NaN        0.0
# 90                                                 NaN        0.0
# 97   /home/se-metrics/root/2d-proccesed//2000_World...        NaN
# 147                                                NaN      435.0
# 253                                                NaN        0.0
# 279  /home/se-metrics/root/2d-proccesed//2008_Japan...  1077013.0
# 311                                                NaN        NaN
# 312  /home/se-metrics/root/2d-proccesed//1997_World...        0.0
# 333                                                NaN        0.0
# 351                                                NaN        0.0
# 414                                                NaN      435.0
# 424                                                NaN        0.0
# 429                                                NaN        0.0
# 439                                                NaN        NaN
# 443                                                NaN        0.0
# 487                                                NaN        0.0
# 504  /home/se-metrics/root/2d-proccesed//1999_World...     1706.0
# 506  /home/se-metrics/root/2d-proccesed//1998_World...        0.0
#
#      IF4_per_module_x  IF4_visible_x  IF4_visible_per_module_x  \
# 55              5.264          558.0                     5.264
# 58                NaN            NaN                       NaN
# 68              0.000            0.0                     0.000
# 90              0.000            0.0                     0.000
# 97                NaN            NaN                       NaN
# 147            15.000          435.0                    15.000
# 253             0.000            0.0                     0.000
# 279          2652.741      1077009.0                  2652.732
# 311               NaN            NaN                       NaN
# 312             0.000            0.0                     0.000
# 333             0.000            0.0                     0.000
# 351             0.000            0.0                     0.000
# 414            15.000          435.0                    15.000
# 424             0.000            0.0                     0.000
# 429             0.000            0.0                     0.000
# 439               NaN            NaN                       NaN
# 443             0.000            0.0                     0.000
# 487             0.000            0.0                     0.000
# 504            74.174         1706.0                    74.174
# 506             0.000            0.0                     0.000
#
#      McCabes_cyclomatic_complexity_x  \
# 55                            4646.0
# 58                               NaN
# 68                             821.0
# 90                             969.0
# 97                               NaN
# 147                           1166.0
# 253                            331.0
# 279                           9915.0
# 311                              NaN
# 312                            223.0
# 333                           2860.0
# 351                           1615.0
# 414                           1166.0
# 424                            253.0
# 429                           5495.0
# 439                              NaN
# 443                           2841.0
# 487                            283.0
# 504                            772.0
# 506                            584.0
#
#      McCabes_cyclomatic_complexity_per_line_of_comment_x  \
# 55                                               1.238
# 58                                                 NaN
# 68                                               2.783
# 90                                               2.893
# 97                                                 NaN
# 147                                              1.565
# 253                                              2.149
# 279                                              0.604
# 311                                                NaN
# 312                                              0.743
# 333                                              1.072
# 351                                              3.283
# 414                                              1.565
# 424                                              2.040
# 429                                              0.589
# 439                                                NaN
# 443                                              2.373
# 487                                              2.339
# 504                                              0.860
# 506                                              7.892
#
#      McCabes_cyclomatic_complexity_per_module_x  Number_exe_files_x  \
# 55                                       43.830                   0
# 58                                          NaN                   0
# 68                                      821.000                   0
# 90                                      969.000                   0
# 97                                          NaN                 117
# 147                                      40.207                   0
# 253                                     331.000                   0
# 279                                      24.421                   3
# 311                                         NaN                   0
# 312                                      22.300                   1
# 333                                     190.667                   0
# 351                                     146.818                   0
# 414                                      40.207                   0
# 424                                     253.000                   0
# 429                                     610.556                   0
# 439                                         NaN                   0
# 443                                     947.000                   0
# 487                                     283.000                   0
# 504                                      33.565                   1
# 506                                     584.000                   4
#
#        ...      results_win_diff  results_win_rate  results_goals_diff  \
# 55     ...                   NaN               NaN                 NaN
# 58     ...                   NaN               NaN                 NaN
# 68     ...                   NaN               NaN                 NaN
# 90     ...                   NaN               NaN                 NaN
# 97     ...                   NaN               NaN                 NaN
# 147    ...                   NaN               NaN                 NaN
# 253    ...                   NaN               NaN                 NaN
# 279    ...                   NaN               NaN                 NaN
# 311    ...                   NaN               NaN                 NaN
# 312    ...                   NaN               NaN                 NaN
# 333    ...                   NaN               NaN                 NaN
# 351    ...                   NaN               NaN                 NaN
# 414    ...                   NaN               NaN                 NaN
# 424    ...                   NaN               NaN                 NaN
# 429    ...                   NaN               NaN                 NaN
# 439    ...                   NaN               NaN                 NaN
# 443    ...                   NaN               NaN                 NaN
# 487    ...                   NaN               NaN                 NaN
# 504    ...                   NaN               NaN                 NaN
# 506    ...                   NaN               NaN                 NaN
#
#      results_loss_rate  team_manual team_alt  exist  length  max     _merge
# 55                 NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 58                 NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 68                 NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 90                 NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 97                 NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 147                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 253                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 279                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 311                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 312                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 333                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 351                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 414                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 424                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 429                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 439                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 443                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 487                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 504                NaN          NaN      NaN    NaN     NaN  NaN  left_only
# 506                NaN          NaN      NaN    NaN     NaN  NaN  left_only
#
# [20 rows x 554 columns]
