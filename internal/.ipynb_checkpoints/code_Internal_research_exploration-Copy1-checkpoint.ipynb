# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from correlation import save_corrlation_matrix,save_scatter

# %%
out_folder = "output_figures"

# %%
df_raw = pd.read_csv('../data/merged-logs_repo.csv')

# %%
df_binary = df_raw[df_raw['is_source']!=True]

# %%
df_binary_red = df_binary[~df_binary.isnull().all(axis=1)]
df_binary_red.shape[0]
# Out:
# 366

# %% [markdown]
# #### Binary code analysis metrics to perfromance metrics corrlation matrix

# %%
corr_pearson = save_corrlation_matrix('Binary',df_binary_red,'pearson','player(.)*','results',
                                      out_folder,x_axis_title_size=0.40,figsize=(10,10))

# %%
corr_spearman = save_corrlation_matrix('Binary', df_binary_red,'spearman','player(.)*','results',out_folder,
                                      x_axis_title_size=0.40,figsize=(10,10))

# %%
melt_corr= corr_pearson.reset_index().melt(id_vars=['index'])
melt_corr= melt_corr[melt_corr['value'].abs()>0.2]

# %%
melt_corr
# Out:
#                                        index            variable     value
# 2    player_fast_block_instructions_info_sum  results_Unnamed: 0  0.215637
# 5          player_fast_blocks_sizes_info_sum  results_Unnamed: 0  0.226970
# 93   player_fast_block_instructions_info_sum    results_win_diff  0.216310
# 96         player_fast_blocks_sizes_info_sum    results_win_diff  0.226765
# 106  player_fast_block_instructions_info_sum    results_win_rate  0.224155
# 109        player_fast_blocks_sizes_info_sum    results_win_rate  0.237784
# 119  player_fast_block_instructions_info_sum  results_goals_diff  0.229215
# 122        player_fast_blocks_sizes_info_sum  results_goals_diff  0.243121
# 135        player_fast_blocks_sizes_info_sum   results_loss_rate -0.201190

# %%
df_binary_red
# Out:
#      Unnamed: 0                    Current_group_location  \
# 1            29       2014_WorldCup_Yushan2014Robocup2014
# 2            37     2014_WorldCup_InfoGraphicsRobocup2014
# 3            49       2014_WorldCup_HELIOS2014Robocup2014
# 5            77      2014_WorldCup_Gliders2014Robocup2014
# 6            91           2014_WorldCup_EnigmaRobocup2014
# 7           115       2014_WorldCup_AUTParsianRobocup2014
# 8           133      2014_WorldCup_WrightEagleRobocup2014
# 10          150            2014_WorldCup_CYRUSRobocup2014
# 11          174             2014_WorldCup_OxsyRobocup2014
# 12          185           2014_WorldCup_HERMESRobocup2014
# 13          201       2014_WorldCup_HfutEngineRobocup2014
# 14          212         2008_WorldCup_AmoyNQ_rc08_release
# 15          264         2008_WorldCup_Ri-one_rc08_release
# 16          282      2008_WorldCup_Dainamite_rc08_release
# 17          317         2008_WorldCup_Helios_rc08_release
# 18          354          2008_WorldCup_NCL08_rc08_release
# 19          378    2008_WorldCup_OPU_hana_2D_rc08_release
# 20          401            2008_WorldCup_ATH_rc08_release
# 21          442           2008_WorldCup_HFut_rc08_release
# 22          487    2008_WorldCup_WrightEagle_rc08_release
# 23          514           2008_WorldCup_Oxsy_rc08_release
# 24          527  2008_WorldCup_Brainstormers_rc08_release
# 25          575         2008_WorldCup_OxBlue_rc08_release
# 26          595                      2011_ChinaOpens_swun
# 27          613                     2011_ChinaOpens_riton
# 28          627                      2011_ChinaOpens_gdut
# 29          657                    2011_ChinaOpens_yushan
# 30          674               2011_ChinaOpens_wrighteagle
# 31          691                      2011_ChinaOpens_tjnu
# 32          704                2011_ChinaOpens_hfutengine
# ..          ...                                       ...
# 377       12496               2008_ChinaOpens_HelliBASH2D
# 378       12513                 2008_ChinaOpens_DesertEgl
# 379       12542                2008_ChinaOpens_HfutEngine
# 380       12571                     2012_ChinaOpens_xmunq
# 381       12595                2012_ChinaOpens_hfutengine
# 383       12631                      2012_ChinaOpens_tjnu
# 384       12638                  2012_ChinaOpens_apollo2d
# 385       12664                   2012_ChinaOpens_tornado
# 386       12681               2012_ChinaOpens_wonderpines
# 387       12694             2012_ChinaOpens_gdut_tiji2012
# 389       12721               2012_ChinaOpens_dreamwing2d
# 390       12735                     2012_ChinaOpens_aua2d
# 392       12778               2012_ChinaOpens_wrighteagle
# 393       12796                 2012_ChinaOpens_csu_yunlu
# 394       12813                2012_ChinaOpens_yushan2012
# 395       12828                      2015_WorldCup_Rhoban
# 396       12869               2015_WorldCup_GDUT-TiJi2015
# 397       12882                  2015_WorldCup_ITAndroids
# 398       12912                  2015_WorldCup_YuShan2015
# 399       12921              2015_WorldCup_HfutEngine2015
# 400       12947                      2015_WorldCup_Phonix
# 401       12970                 2015_WorldCup_WrightEagle
# 402       12976                  2015_WorldCup_Genius2015
# 403       13005             2015_WorldCup_rione2015-07-21
# 404       13017                 2015_WorldCup_Gliders2015
# 405       13040                      2015_WorldCup_HERMES
# 406       13063                      2015_WorldCup_Jaeger
# 407       13079                  2015_WorldCup_HELIOS2015
# 408       13111                   2015_WorldCup_CSU_Yunlu
# 409       13124                      2015_WorldCup_MT2015
#
#                                              Exe_files  IF4  IF4_per_module  \
# 1    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 2    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 3    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 5    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 6    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 7    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 8    /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 10   /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 11   /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 12   /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 13   /home/se-metrics/root/2d-proccesed//2014_World...  NaN             NaN
# 14   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 15   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 16                                                 NaN  NaN             NaN
# 17   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 18   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 19   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 20   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 21   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 22   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 23   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 24   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 25   /home/se-metrics/root/2d-proccesed//2008_World...  NaN             NaN
# 26   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 27   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 28   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 29   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 30   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 31   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# 32   /home/se-metrics/root/2d-proccesed//2011_China...  NaN             NaN
# ..                                                 ...  ...             ...
# 377  /home/se-metrics/root/2d-proccesed//2008_China...  NaN             NaN
# 378  /home/se-metrics/root/2d-proccesed//2008_China...  NaN             NaN
# 379  /home/se-metrics/root/2d-proccesed//2008_China...  NaN             NaN
# 380  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 381  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 383  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 384  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 385  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 386  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 387  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 389  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 390  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 392  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 393  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 394  /home/se-metrics/root/2d-proccesed//2012_China...  NaN             NaN
# 395  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 396  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 397  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 398  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 399  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 400  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 401  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 402  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 403  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 404  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 405  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 406  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 407  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 408  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
# 409  /home/se-metrics/root/2d-proccesed//2015_World...  NaN             NaN
#
#      IF4_visible  IF4_visible_per_module  McCabes_cyclomatic_complexity  \
# 1            NaN                     NaN                            NaN
# 2            NaN                     NaN                            NaN
# 3            NaN                     NaN                            NaN
# 5            NaN                     NaN                            NaN
# 6            NaN                     NaN                            NaN
# 7            NaN                     NaN                            NaN
# 8            NaN                     NaN                            NaN
# 10           NaN                     NaN                            NaN
# 11           NaN                     NaN                            NaN
# 12           NaN                     NaN                            NaN
# 13           NaN                     NaN                            NaN
# 14           NaN                     NaN                            NaN
# 15           NaN                     NaN                            NaN
# 16           NaN                     NaN                            NaN
# 17           NaN                     NaN                            NaN
# 18           NaN                     NaN                            NaN
# 19           NaN                     NaN                            NaN
# 20           NaN                     NaN                            NaN
# 21           NaN                     NaN                            NaN
# 22           NaN                     NaN                            NaN
# 23           NaN                     NaN                            NaN
# 24           NaN                     NaN                            NaN
# 25           NaN                     NaN                            NaN
# 26           NaN                     NaN                            NaN
# 27           NaN                     NaN                            NaN
# 28           NaN                     NaN                            NaN
# 29           NaN                     NaN                            NaN
# 30           NaN                     NaN                            NaN
# 31           NaN                     NaN                            NaN
# 32           NaN                     NaN                            NaN
# ..           ...                     ...                            ...
# 377          NaN                     NaN                            NaN
# 378          NaN                     NaN                            NaN
# 379          NaN                     NaN                            NaN
# 380          NaN                     NaN                            NaN
# 381          NaN                     NaN                            NaN
# 383          NaN                     NaN                            NaN
# 384          NaN                     NaN                            NaN
# 385          NaN                     NaN                            NaN
# 386          NaN                     NaN                            NaN
# 387          NaN                     NaN                            NaN
# 389          NaN                     NaN                            NaN
# 390          NaN                     NaN                            NaN
# 392          NaN                     NaN                            NaN
# 393          NaN                     NaN                            NaN
# 394          NaN                     NaN                            NaN
# 395          NaN                     NaN                            NaN
# 396          NaN                     NaN                            NaN
# 397          NaN                     NaN                            NaN
# 398          NaN                     NaN                            NaN
# 399          NaN                     NaN                            NaN
# 400          NaN                     NaN                            NaN
# 401          NaN                     NaN                            NaN
# 402          NaN                     NaN                            NaN
# 403          NaN                     NaN                            NaN
# 404          NaN                     NaN                            NaN
# 405          NaN                     NaN                            NaN
# 406          NaN                     NaN                            NaN
# 407          NaN                     NaN                            NaN
# 408          NaN                     NaN                            NaN
# 409          NaN                     NaN                            NaN
#
#      McCabes_cyclomatic_complexity_per_line_of_comment  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# ..                                                 ...
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 389                                                NaN
# 390                                                NaN
# 392                                                NaN
# 393                                                NaN
# 394                                                NaN
# 395                                                NaN
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
# 402                                                NaN
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                                NaN
# 409                                                NaN
#
#      McCabes_cyclomatic_complexity_per_module  ...    results_tie  \
# 1                                         NaN  ...            1.0
# 2                                         NaN  ...            2.0
# 3                                         NaN  ...            3.0
# 5                                         NaN  ...            2.0
# 6                                         NaN  ...            1.0
# 7                                         NaN  ...            2.0
# 8                                         NaN  ...            3.0
# 10                                        NaN  ...            4.0
# 11                                        NaN  ...            6.0
# 12                                        NaN  ...            6.0
# 13                                        NaN  ...            0.0
# 14                                        NaN  ...            0.0
# 15                                        NaN  ...            2.0
# 16                                        NaN  ...            6.0
# 17                                        NaN  ...            1.0
# 18                                        NaN  ...            4.0
# 19                                        NaN  ...            2.0
# 20                                        NaN  ...            2.0
# 21                                        NaN  ...            2.0
# 22                                        NaN  ...            1.0
# 23                                        NaN  ...            3.0
# 24                                        NaN  ...            0.0
# 25                                        NaN  ...            6.0
# 26                                        NaN  ...            1.0
# 27                                        NaN  ...            2.0
# 28                                        NaN  ...            0.0
# 29                                        NaN  ...            0.0
# 30                                        NaN  ...            1.0
# 31                                        NaN  ...            0.0
# 32                                        NaN  ...            0.0
# ..                                        ...  ...            ...
# 377                                       NaN  ...            0.0
# 378                                       NaN  ...            0.0
# 379                                       NaN  ...            0.0
# 380                                       NaN  ...            0.0
# 381                                       NaN  ...            0.0
# 383                                       NaN  ...            0.0
# 384                                       NaN  ...            0.0
# 385                                       NaN  ...            0.0
# 386                                       NaN  ...            0.0
# 387                                       NaN  ...            1.0
# 389                                       NaN  ...            0.0
# 390                                       NaN  ...            0.0
# 392                                       NaN  ...            1.0
# 393                                       NaN  ...            0.0
# 394                                       NaN  ...            1.0
# 395                                       NaN  ...            0.0
# 396                                       NaN  ...            6.0
# 397                                       NaN  ...            5.0
# 398                                       NaN  ...            4.0
# 399                                       NaN  ...            3.0
# 400                                       NaN  ...           10.0
# 401                                       NaN  ...            2.0
# 402                                       NaN  ...            5.0
# 403                                       NaN  ...            5.0
# 404                                       NaN  ...            4.0
# 405                                       NaN  ...            4.0
# 406                                       NaN  ...            2.0
# 407                                       NaN  ...            3.0
# 408                                       NaN  ...            7.0
# 409                                       NaN  ...            4.0
#
#      results_win  results_win_diff  results_win_rate  results_goals_diff  \
# 1            8.0          0.000000          0.470588            0.470588
# 2            7.0         -0.058824          0.411765            0.117647
# 3           11.0          0.562500          0.687500            1.875000
# 5           13.0          0.647059          0.764706            2.176471
# 6            0.0         -0.944444          0.000000           -3.611111
# 7            5.0         -0.200000          0.333333           -0.666667
# 8           13.0          0.611111          0.722222            2.333333
# 10           8.0          0.176471          0.470588            0.058824
# 11           7.0          0.176471          0.411765            0.764706
# 12           3.0         -0.294118          0.176471           -0.764706
# 13           5.0         -0.333333          0.333333           -1.600000
# 14           7.0          0.750000          0.875000            3.000000
# 15           8.0          0.058824          0.470588           -0.352941
# 16          15.0          0.333333          0.555556            0.740741
# 17           9.0          0.461538          0.692308            2.153846
# 18          13.0          0.071429          0.464286           -0.107143
# 19           6.0          0.166667          0.500000            0.500000
# 20           0.0         -0.818182          0.000000           -1.909091
# 21          11.0          0.200000          0.550000            1.050000
# 22          11.0          0.642857          0.785714            2.071429
# 23          22.0          0.516129          0.709677            1.548387
# 24          10.0          0.818182          0.909091            2.909091
# 25          15.0          0.200000          0.500000            0.533333
# 26           6.0          0.625000          0.750000            1.875000
# 27           3.0         -0.384615          0.230769           -0.692308
# 28           9.0          0.500000          0.750000            1.916667
# 29           9.0          0.384615          0.692308            2.076923
# 30          11.0          0.769231          0.846154            4.076923
# 31           6.0          0.200000          0.600000            1.200000
# 32           1.0         -0.846154          0.076923           -3.076923
# ..           ...               ...               ...                 ...
# 377          7.0         -0.066667          0.466667           -1.200000
# 378         10.0          1.000000          1.000000            5.000000
# 379          9.0          0.500000          0.750000            3.250000
# 380          4.0          0.142857          0.571429            0.142857
# 381          1.0         -0.333333          0.333333           -0.666667
# 383          6.0          0.500000          0.750000            0.750000
# 384          2.0         -0.333333          0.333333           -1.166667
# 385          0.0         -1.000000          0.000000           -8.333333
# 386          4.0          0.333333          0.666667            0.500000
# 387          3.0          0.166667          0.500000            0.666667
# 389          2.0         -0.333333          0.333333           -0.666667
# 390          3.0          0.000000          0.500000            0.666667
# 392          8.0          0.700000          0.800000            3.500000
# 393          4.0          0.333333          0.666667            1.666667
# 394          4.0          0.285714          0.571429            1.571429
# 395          0.0         -1.000000          0.000000           -2.375000
# 396         10.0          0.181818          0.454545            0.000000
# 397          5.0         -0.347826          0.217391           -0.217391
# 398         12.0          0.166667          0.500000            0.541667
# 399          7.0         -0.260870          0.304348           -1.043478
# 400          7.0          0.090909          0.318182            0.000000
# 401         16.0          0.619048          0.761905            2.047619
# 402          6.0         -0.190476          0.285714           -0.476190
# 403          4.0         -0.409091          0.181818           -1.409091
# 404         18.0          0.739130          0.782609            2.521739
# 405          8.0         -0.130435          0.347826           -0.608696
# 406          3.0         -0.652174          0.130435           -2.260870
# 407         17.0          0.761905          0.809524            2.047619
# 408          8.0          0.045455          0.363636            0.409091
# 409          6.0         -0.272727          0.272727           -0.681818
#
#      results_loss_rate  results_rank      team_manual  \
# 1             0.470588           0.0              NaN
# 2             0.470588           0.0              NaN
# 3             0.125000           0.0              NaN
# 5             0.117647           2.0              NaN
# 6             0.944444           0.0              NaN
# 7             0.533333           0.0              NaN
# 8             0.111111           3.0              NaN
# 10            0.294118           0.0              NaN
# 11            0.235294           1.0              NaN
# 12            0.470588           0.0              NaN
# 13            0.666667           0.0              NaN
# 14            0.125000           0.0              NaN
# 15            0.411765           0.0              NaN
# 16            0.222222           0.0              NaN
# 17            0.230769           1.0       helios2008
# 18            0.392857           0.0              NaN
# 19            0.333333           0.0              NaN
# 20            0.818182           0.0              NaN
# 21            0.350000           0.0     hfutengine2d
# 22            0.142857           2.0           we2008
# 23            0.193548           0.0              NaN
# 24            0.090909           3.0  brainstormers08
# 25            0.300000           0.0              NaN
# 26            0.125000           0.0              NaN
# 27            0.615385           0.0              NaN
# 28            0.250000           0.0              NaN
# 29            0.307692           0.0              NaN
# 30            0.076923           0.0              NaN
# 31            0.400000           0.0              NaN
# 32            0.923077           0.0              NaN
# ..                 ...           ...              ...
# 377           0.533333           0.0              NaN
# 378           0.000000           0.0              NaN
# 379           0.250000           0.0              NaN
# 380           0.428571           0.0              NaN
# 381           0.666667           0.0              NaN
# 383           0.250000           0.0              NaN
# 384           0.666667           0.0              NaN
# 385           1.000000           0.0              NaN
# 386           0.333333           0.0              NaN
# 387           0.333333           0.0              NaN
# 389           0.666667           0.0              NaN
# 390           0.500000           0.0              NaN
# 392           0.100000           0.0              NaN
# 393           0.333333           0.0              NaN
# 394           0.285714           0.0              NaN
# 395           1.000000           0.0              NaN
# 396           0.272727           0.0              NaN
# 397           0.565217           0.0              NaN
# 398           0.333333           0.0              NaN
# 399           0.565217           0.0              NaN
# 400           0.227273           0.0              NaN
# 401           0.142857           3.0              NaN
# 402           0.476190           0.0              NaN
# 403           0.590909           0.0              NaN
# 404           0.043478           1.0              NaN
# 405           0.478261           0.0              NaN
# 406           0.782609           0.0              NaN
# 407           0.047619           2.0              NaN
# 408           0.318182           0.0              NaN
# 409           0.545455           0.0              NaN
#
#                        team_alt  exist
# 1                    yushan2014   True
# 2                  infographics   True
# 3                    helios2014   True
# 5                   gliders2014   True
# 6                        enigma   True
# 7                       parsian   True
# 8                   wrighteagle   True
# 10                    cyrus2014   True
# 11                         oxsy   True
# 12                       hermes   True
# 13                   hfutengine   True
# 14                       amoynq   True
# 15                          one   True
# 16                    dainamite   True
# 17          Helios_rc08_release   True
# 18                        ncl08   True
# 19                         hana   True
# 20                          ath   True
# 21            HFut_rc08_release   True
# 22     WrightEagle_rc08_release   True
# 23                         oxsy   True
# 24   Brainstormers_rc08_release   True
# 25                     oxblue08   True
# 26                         swun   True
# 27                        riton   True
# 28                     gdut2011   True
# 29                   yushan2011   True
# 30                  wrighteagle   True
# 31                         tjnu   True
# 32               hfutengine2011   True
# ..                          ...    ...
# 377                   hellibash   True
# 378                   desertegl   True
# 379                    engine2d   True
# 380                       xmunq   True
# 381              hfutengine2012   True
# 383                        tjnu   True
# 384                    apollo2d   True
# 385                     tornado   True
# 386                 wonderpines   True
# 387                        tiji   True
# 389                 dreamwing2d   True
# 390                       aua2d   True
# 392                 wrighteagle   True
# 393                       yunlu   True
# 394                  yushan2012   True
# 395                      rhoban   True
# 396                    tiji2015   True
# 397                  itandroids   True
# 398                  yushan2015   True
# 399              hfutengine2015   True
# 400                      phonix   True
# 401                 wrighteagle   True
# 402                  genius2015   True
# 403                     one2015   True
# 404                 gliders2015   True
# 405                      hermes   True
# 406                      jaeger   True
# 407                  helios2015   True
# 408                       yunlu   True
# 409                      mt2015   True
#
# [366 rows x 287 columns]

# %%
for index, row in melt_corr.iterrows():
    save_scatter(df_binary_red,row['index'],row['variable'],out_folder)

# %% [markdown]
# ## Code repositories

# %%
df_code = df_raw[df_raw['is_source']==True]

# %%
df_code.shape[0]
# Out:
# 44

# %%
corr_pearson = save_corrlation_matrix('Code', df_code,'pearson','analizo(.)*mean','results',
                                      out_folder,x_axis_title_size=0.20,figsize=(10,10)
                                     )

# %%
corr_pearson = save_corrlation_matrix('Code', df_code,'spearman','analizo(.)*mean','results',out_folder)

# %%
melt_corr= corr_pearson.reset_index().melt(id_vars=['index'])
melt_corr= melt_corr[melt_corr['value'].abs()>0.3]

# %%
melt_corr
# Out:
#                  index           variable     value
# 41    analizo_noa_mean          results_S -0.403488
# 43    analizo_nom_mean          results_S -0.451488
# 44    analizo_npa_mean          results_S -0.422463
# 45    analizo_npm_mean          results_S -0.380277
# 46    analizo_rfc_mean          results_S -0.457841
# 47     analizo_sc_mean          results_S -0.370311
# 52    analizo_cbo_mean          results_R -0.306560
# 59    analizo_nom_mean          results_R -0.322288
# 81   analizo_accm_mean        results_tie -0.325099
# 90    analizo_noc_mean        results_tie  0.317190
# 105   analizo_noa_mean        results_win -0.348904
# 107   analizo_nom_mean        results_win -0.388998
# 108   analizo_npa_mean        results_win -0.394898
# 109   analizo_npm_mean        results_win -0.307917
# 110   analizo_rfc_mean        results_win -0.410707
# 111    analizo_sc_mean        results_win -0.312376
# 170   analizo_noc_mean  results_loss_rate -0.300515

# %%
for index, row in melt_corr.iterrows():
    save_scatter(df_code,row['index'],row['variable'],out_folder)
