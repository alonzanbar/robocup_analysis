# %%
import matplotlib
import  pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

# %%
df1 =  pd.read_csv('data/robo2d-18_09_2018.csv')

# %%
df_r =  df1[df1['is_source']==True]
df_r = df_r.rename(index=str,columns={'new_dir':'folder'})

# %%
df_r.sort_values('year').plot.barh(x='folder',y='analizo_accm_mean',figsize=(7,30))

# %%
df_r.groupby(['year','source_lang']).agg(['count','mean'])['analizo_accm_mean']
# Out:
#                   count      mean
# year source_lang
# 1996 C                3  9.988174
# 1997 C                5  4.700791
# 1998 C                3  3.471830
# 1999 C                1  4.693021
#      C++              1  1.780985
#      Java             2  2.193118
# 2000 C                1  1.627982
#      Java             1  2.200852
# 2001 C                2  1.846049
#      Java             1  1.353191
# 2002 C++              1  2.406056
# 2004 C++              1  2.660519
#      Java             0       NaN
# 2007 Java             1  1.915751
# 2008 C++              9  2.152909
# 2009 C++             10  4.240528
# 2011 C++              3  2.374842
# 2012 C++             10  3.036511
# 2014 C++              9  1.657464
# 2015 C++              1  2.492268
# 2016 C++              5  2.633899

# %%
df_r.groupby(['competition','year','source_lang']).agg(['count','mean']).sort_values(['competition','year'])['analizo_accm_mean']
# Out:
#                               count      mean
# competition year source_lang
# ChinaOpens  2012 C++              3  1.968671
# JapanOpens  2008 C++              9  2.152909
#             2009 C++              7  4.147499
#             2011 C++              3  2.374842
# LARC        2014 C++              5  1.755830
# PRIMA       2009 C++              3  4.457596
# WorldCup    1996 C                3  9.988174
#             1997 C                5  4.700791
#             1998 C                3  3.471830
#             1999 C                1  4.693021
#                  C++              1  1.780985
#                  Java             2  2.193118
#             2000 C                1  1.627982
#                  Java             1  2.200852
#             2001 C                2  1.846049
#                  Java             1  1.353191
#             2002 C++              1  2.406056
#             2004 C++              1  2.660519
#                  Java             0       NaN
#             2007 Java             1  1.915751
#             2012 C++              7  3.494156
#             2014 C++              4  1.534507
#             2015 C++              1  2.492268
#             2016 C++              5  2.633899

# %%
df_bin_code = df_r[df_r['player_function_cc_radare2_mean'].notnull()]
df_bin_code.count()
# Out:
# Current_group_location                                 36
# Exe_files                                              36
# IF4                                                    33
# IF4_per_module                                         33
# IF4_visible                                            33
# IF4_visible_per_module                                 33
# McCabes_cyclomatic_complexity                          33
# McCabes_cyclomatic_complexity_per_line_of_comment      33
# McCabes_cyclomatic_complexity_per_module               33
# Number_exe_files                                       36
# Number_libraries_Total                                 36
# Number_lines_Total                                     36
# Number_of_binaries                                     36
# analizo_acc_kurtosis                                   35
# analizo_acc_mean                                       35
# analizo_acc_mode                                       35
# analizo_acc_quantile_lower                             35
# analizo_acc_quantile_max                               35
# analizo_acc_quantile_median                            35
# analizo_acc_quantile_min                               35
# analizo_acc_quantile_ninety_five                       35
# analizo_acc_quantile_upper                             35
# analizo_acc_skewness                                   35
# analizo_acc_standard_deviation                         35
# analizo_acc_sum                                        35
# analizo_acc_variance                                   35
# analizo_accm_kurtosis                                  35
# analizo_accm_mean                                      35
# analizo_accm_mode                                      35
# analizo_accm_quantile_lower                            35
#                                                        ..
# dir_to_zip                                             36
# group_name                                             36
# is_source                                              36
# lines_of_code                                          33
# lines_of_code_per_line_of_comment                      33
# lines_of_code_per_module                               33
# lines_of_comment                                       33
# lines_of_comment_per_module                            33
# folder                                                 36
# new_dir_name                                           36
# number_of_modules                                      33
# player_fast_block_instructions_info_max                23
# player_fast_block_instructions_info_min                23
# player_fast_block_instructions_info_std                23
# player_fast_block_instructions_info_sum                23
# player_fast_blocks_sizes_info_max                      23
# player_fast_blocks_sizes_info_min                      23
# player_fast_blocks_sizes_info_std                      23
# player_fast_blocks_sizes_info_sum                      23
# player_fast_complex_mccabe                             23
# player_fast_number_of_CFG_nodes_that_return_a_value    23
# player_fast_simple_mccabe                              23
# player_fast_system_calls_count                         23
# player_function_cc_radare2_max                         36
# player_function_cc_radare2_mean                        36
# player_function_cc_radare2_std                         36
# player_function_cc_radare2_sum                         36
# rejected_lines_of_code                                 33
# source_lang                                            36
# year                                                   36
# Length: 270, dtype: int64

# %%
df_bin_code.plot.scatter(x='player_function_cc_radare2_mean',y='analizo_accm_mean')
