# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('competition_results.csv')

# %%
groupd_df = df.groupby(['competition','year','teamname']).sum()

# %%
groupd_df.head()
# Out:
#                               avg_goal_diff  avg_goals_scored  drawn  \
# competition year teamname
# CBR         2013 Expertinos        3.000000          8.000000      0
#                  Furgbot           9.166667         21.833333      3
#                  GPR2D_2013        5.166667         12.166667      2
#                  HELIOS_base       0.000000          0.000000      2
#                  ITAndroids       22.333333         35.500000      0
#
#                               goals_received  goals_scored  lost  matches  \
# competition year teamname
# CBR         2013 Expertinos                5             8     1        2
#                  Furgbot                  26            53     5       14
#                  GPR2D_2013               15            36     5       10
#                  HELIOS_base               0             0     0        2
#                  ITAndroids               17            80     3       15
#
# ...

# %%
groupd_df['win_prec'] = groupd_df['won'] / groupd_df['matches']

# %%
groupd_df
# Out:
#                                   avg_goal_diff  avg_goals_scored  drawn  \
# competition year teamname
# CBR         2013 Expertinos            3.000000          8.000000      0
#                  Furgbot               9.166667         21.833333      3
#                  GPR2D_2013            5.166667         12.166667      2
#                  HELIOS_base           0.000000          0.000000      2
#                  ITAndroids           22.333333         35.500000      0
#                  UAISoccer2D           3.333333         17.333333      4
#                  Warthog               0.833333         12.000000      1
#                  expertinos          -53.333333          0.000000      0
#                  iBots                10.833333         21.666667      1
#                  robocap              -1.333333         10.000000      1
# DutchOpens  2012 FCPortugal           -6.000000          3.250000      6
# ...
